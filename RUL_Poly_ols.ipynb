# %%
import random, numpy
import numpy as np
import pandas as pd

random.seed(30)

max = 3.0
min = 1
desired = 800
step = float(max - min) / desired
window = 3.0
numbers_1 = [x - (random.random() * window) + (window / 2.0) for x in numpy.arange(min,max, step)]

# %%
numbers_1
# Out:
# [0.8827553061825681,
#  1.6349106690808384,
#  2.414889274346619,
#  0.5465927383217144,
#  1.8799739133508064,
#  1.740669075061172,
#  1.3234052121003175,
#  0.5927655386759814,
#  -0.44643363121116497,
#  1.1379009698121245,
#  -0.4554550228050065,
#  -0.45021598247588424,
#  1.8019733932796695,
#  2.314564661385975,
#  2.055296933311145,
#  0.011791805563132307,
#  0.7413358131611938,
#  -0.20988799456758178,
#  -0.37150732230881633,
#  0.58422853823601,
#  0.944385653389916,
#  2.3496069052499946,
#  2.484469810829655,
#  0.1416171392168577,
#  0.544090858404334,
#  0.273464774441194,
#  0.868042595934416,
#  0.545818722283173,
#  0.6538315435733453,
#  -0.11302695147630093,
#  2.2397499439091173,
#  1.0941487410572275,
#  1.652417844921082,
#  0.09446523065963008,
#  -0.046230957323114996,
#  1.8314094966576127,
#  2.348972559757422,
#  1.8628291170436855,
#  1.6511549860568966,
#  0.28859491194610865,
#  1.3708213944047252,
#  0.3528011337119956,
#  1.7021359197998625,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

plt.plot(numbers_1)
plt.show()

# %%
max = 15.0
min = 3
desired = 500
step = float(max - min) / desired
window = 3.0
numbers_2 = [x - (random.random() * window) + (window / 2.0) for x in numpy.arange(min,max, step)]

# %%
plt.plot(numbers_2)
plt.show()

# %%
vib = np.concatenate((numbers_1, numbers_2), axis = 0)

# %%
vib.shape
# Out:
# (1300,)

# %%
plt.plot(vib)
plt.show()

# %%
dataset = pd.DataFrame({'vib': vib[:]})

# %%
dataset
# Out:
#             vib
# 0      0.882755
# 1      1.634911
# 2      2.414889
# 3      0.546593
# 4      1.879974
# ...         ...
# 1295  13.542718
# 1296  15.616184
# 1297  15.177960
# 1298  16.026703
# 1299  14.405925
#
# [1300 rows x 1 columns]

# %%
dataset.shape
# Out:
# (1300, 1)

# %%
print(dataset.loc[0][0])
# Out:
# 0.8827553061825681

# %%
n = len(dataset)

# %%
a = []

for i in range(n):
    #print(dataset.loc[i][0])
    square= dataset.loc[i][0] ** 2
    a.append(square)
    #print(square)

# %%
a
# Out:
# [0.7792569305934797,
#  2.6729328958743546,
#  5.831690207354339,
#  0.29876362158603015,
#  3.5343019148795456,
#  3.029928828874316,
#  1.7514013554142862,
#  0.35137098384182636,
#  0.19930298707638644,
#  1.2948186170993736,
#  0.20743927779830898,
#  0.2026944308767257,
#  3.2471081100878467,
#  5.357209571736774,
#  4.224245484078198,
#  0.00013904667843871803,
#  0.5495787878753684,
#  0.04405297026360124,
#  0.13801769052906673,
#  0.34132298488938495,
#  0.8918642623286985,
#  5.520652609198457,
#  6.172590240923941,
#  0.020055414119966856,
#  0.296034862199165,
#  0.07478298286017311,
#  0.7534979483565598,
#  0.2979180775948355,
#  0.4274956873715033,
#  0.012775091760026084,
#  5.016479811240894,
#  1.1971614675571158,
#  2.730484734213633,
#  0.008923679803577115,
#  0.0021373014150116803,
#  3.35406074444769,
#  5.517672086493335,
#  3.470132319305757,
#  2.72631278798055,
#  0.0832870232011822,
#  1.879151295357715,
#  0.1244686399484694,
#  2.8972666894729238,
# ...

# %%
m = len(a)
print(m)
# Out:
# 1300

# %%
print(a[1])
# Out:
# 2.6729328958743546

# %%
import math
vib_rms = []
square_sum = 0

for i in range(1, m+1):
    square_sum = square_sum + a[i-1]
    rms = math.sqrt(square_sum/i) 
    vib_rms.append(rms)
    print(square_sum, rms)
# Out:
# 0.7792569305934797 0.8827553061825681
# 3.4521898264678343 1.3138093138785085
# 9.283880033822173 1.7591551034348063
# 9.582643655408203 1.5477922708981495
# 13.116945570287749 1.619687968115325
# 16.146874399162066 1.6404711924302962
# 17.898275754576353 1.5990298735070745
# 18.24964673841818 1.5103661285603145
# 18.448949725494565 1.4317413533291303
# 19.74376834259394 1.4051252023429777
# 19.951207620392246 1.346753929754202
# 20.15390205126897 1.2959520969564222
# 23.40101016135682 1.341669745026605
# 28.758219733093593 1.433233600067982
# 32.98246521717179 1.4828455801188873
# 32.982604263850234 1.4357620856153848
# 33.5321830517256 1.4044505530576215
# 33.5762360219892 1.365776865255107
# 33.71425371251827 1.3320789788604932
# 34.05557669740766 1.304905680449887
# 34.947440959736355 1.2900247498499944
# 40.46809356893481 1.3562664924667076
# 46.64068380985875 1.4240280256441393
# 46.660739223978716 1.3943448166310153
# 46.95677408617788 1.3705002602871388
# ...

# %%
vib_rms
# Out:
# [0.8827553061825681,
#  1.3138093138785085,
#  1.7591551034348063,
#  1.5477922708981495,
#  1.619687968115325,
#  1.6404711924302962,
#  1.5990298735070745,
#  1.5103661285603145,
#  1.4317413533291303,
#  1.4051252023429777,
#  1.346753929754202,
#  1.2959520969564222,
#  1.341669745026605,
#  1.433233600067982,
#  1.4828455801188873,
#  1.4357620856153848,
#  1.4044505530576215,
#  1.365776865255107,
#  1.3320789788604932,
#  1.304905680449887,
#  1.2900247498499944,
#  1.3562664924667076,
#  1.4240280256441393,
#  1.3943448166310153,
#  1.3705002602871388,
#  1.34495577663983,
#  1.3303446367374496,
#  1.3104384911573554,
#  1.2933579495246679,
#  1.2717867205120124,
#  1.314187148323299,
#  1.307871423737333,
#  1.319634590000289,
#  1.3001843033035536,
#  1.2814994662319965,
#  1.2999197797129092,
#  1.339121976351833,
#  1.3554985101488444,
#  1.363880294079703,
#  1.3474967145579588,
#  1.348070410742861,
#  1.3330373102795299,
#  1.342773790491757,
#  1.3365886294332514,
# ...

# %%
plt.plot(vib_rms)
plt.show()

# %%
#vib_rms.index(5.507863530746851)

# %%
#x = np.linspace(1,1300,1300)

# %%
#x

# %%
y = vib_rms

# %%
#y = np.array(y)

# %%
#y

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

x = np.linspace(1,1300,1300)
y = np.array(y[:1300])

'''
x = x.reshape(-1,1)


poly = PolynomialFeatures(degree = 3) 
X_poly = poly.fit_transform(x) 
  
poly.fit(X_poly, y) 
lin2 = LinearRegression() 
lin2.fit(X_poly, y) 

y_poly_pred = lin2.predict(X_poly)

plt.scatter(x, y, color = 'blue') 
  
plt.plot(x, lin2.predict(poly.fit_transform(x)), color = 'red')
plt.axhline(y = 5.5, color = 'g', linestyle = '-')
plt.title('Polynomial Regression') 
plt.xlabel('Time') 
plt.ylabel('Vib_RMS') 
plt.show() 

#print(lin2.intercept_, lin2.coef_)

#print(lin2.intercept_)
#print(lin2.coef_[0])
#print(lin2.coef_[1])
#print(lin2.coef_[2])
#print(lin2.coef_[3])

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)

#print(rmse)
print("R_Square :" ,r2)
#lin2.coef_.shape
print(x[1279,0])
'''

x= x[:,np.newaxis]
y= y[:,np.newaxis]

inds = x.ravel().argsort()  # Sort x values and get index    
x = x.ravel()[inds].reshape(-1,1)
y = y[inds] #Sort y according to x sorted index

print(x.shape)
print(y.shape)

#Plot
plt.scatter(x,y)
# Out:
# (1300, 1)
# (1300, 1)

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features= PolynomialFeatures(degree=3)
xp = polynomial_features.fit_transform(x)
xp.shape
# Out:
# (1300, 4)

# %%
import statsmodels.api as sm

model = sm.OLS(y, xp).fit()
ypred = model.predict(xp) 

ypred.shape
# Out:
# (1300,)

# %%
plt.scatter(x,y)
plt.plot(x,ypred, color = 'red')

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.169e+05
# Date:                Thu, 15 Oct 2020   Prob (F-statistic):               0.00
# Time:                        10:47:40   Log-Likelihood:                 1476.8
# No. Observations:                1300   AIC:                            -2946.
# Df Residuals:                    1296   BIC:                            -2925.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1221      0.009    129.607      0.000       1.105       1.139
# ...

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std
_, upper,lower = wls_prediction_std(model)

plt.scatter(x,y)
plt.plot(x,ypred, color = 'r')
plt.plot(x,upper,'--',label="Upper") # confid. intrvl
plt.plot(x,lower,':',label="lower")
plt.legend(loc='upper left')

# %%
df = pd.read_html(model.summary().tables[1].as_html(),header=0,index_col=0)[0]

# %%
df
# Out:
#                coef       std err        t  P>|t|        [0.025        0.975]
# const  1.122100e+00  9.000000e-03  129.607    0.0  1.105000e+00  1.139000e+00
# x1     3.600000e-03  5.760000e-05   62.802    0.0  4.000000e-03  4.000000e-03
# x2    -7.336000e-06  1.030000e-07  -71.303    0.0 -7.540000e-06 -7.130000e-06
# x3     5.886000e-09  5.200000e-11  113.229    0.0  5.780000e-09  5.990000e-09

# %%
c = df['[0.025'].values[3]
c
# Out:
# 5.7799999999999995e-09

# %%
from sympy.solvers import solve
from sympy import Symbol, exp

# %%
z = Symbol('z')
#expr = lin2.intercept_ + lin2.coef_[0]*pow(z,0) + lin2.coef_[1]*pow(z,1) + lin2.coef_[2]*pow(z,2) + lin2.coef_[3]*pow(z,3)
expr = df['[0.025'].values[0] + df['[0.025'].values[1]*pow(z,1) + df['[0.025'].values[2]*pow(z,2) + df['[0.025'].values[3]*pow(z,3)

expr
# Out:
# 5.78e-9*z**3 - 7.54e-6*z**2 + 0.004*z + 1.105

# %%
#x = Symbol('x', real = True, positive = True)
z = Symbol('z', positive = True, real = True) 
remaining_1 = solve(df['[0.025'].values[0] + df['[0.025'].values[1]*pow(z,1) + df['[0.025'].values[2]*pow(z,2) + df['[0.025'].values[3]*pow(z,3) - 5.5 , z)
remaining_2 = solve(df['0.975]'].values[0] + df['0.975]'].values[1]*pow(z,1) + df['0.975]'].values[2]*pow(z,2) + df['0.975]'].values[3]*pow(z,3) - 5.5 , z)
print(remaining_1)
print(remaining_2)
# Out:
# [1240.68635370170]
# [1157.01334104586]

# %%
RUL = remaining[0] - x[-1,0]
print(RUL)
# Out:
# -59.3136462983002

# %%
#def func(x):
    #return lin2.intercept_ + lin2.coef_[0]*pow(x,0) + lin2.coef_[1]*pow(x,1) + lin2.coef_[2]*pow(x,2) + lin2.coef_[3]*pow(x,3)
    #return lin2.intercept_ + lin2.coef_[0]*pow(x,0) + lin2.coef_[1]*pow(x,1) + lin2.coef_[2]*pow(x,2)

# %%
#func(2400)

# %%
#vib_rms[400]

# %%
np.where(np.array(vib_rms)>(5.5*0.5))

# %%
import numpy as np
import matplotlib.pyplot as plt 

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

x = np.linspace(1,1280,1280)
y = np.array(y[:1280])
x = x.reshape(-1,1)



x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

rmses = []
degrees = np.arange(1, 10)
min_rmse, min_deg = 1e10, 0

for deg in degrees:

    # Train features
    poly_features = PolynomialFeatures(degree=deg, include_bias=False)
    x_poly_train = poly_features.fit_transform(x_train)

    # Linear regression
    poly_reg = LinearRegression()
    poly_reg.fit(x_poly_train, y_train)

    # Compare with test data
    x_poly_test = poly_features.fit_transform(x_test)
    poly_predict = poly_reg.predict(x_poly_test)
    poly_mse = mean_squared_error(y_test, poly_predict)
    poly_rmse = np.sqrt(poly_mse)
    rmses.append(poly_rmse)
    
    # Cross-validation of degree
    if min_rmse > poly_rmse:
        min_rmse = poly_rmse
        min_deg = deg

# Plot and present results
print('Best degree {} with RMSE {}'.format(min_deg, min_rmse))
        
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(degrees, rmses)
ax.set_yscale('log')
ax.set_xlabel('Degree')
ax.set_ylabel('RMSE')
